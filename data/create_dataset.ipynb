# %% [markdown]
# # Download and Store Data

# %% [markdown]
# This notebook contains information on downloading the Yahoo Finance stock prices and a few other sources that we  would use for our automated trading system.
#
# Let's start with installing a few libraries that we are going to use:

# %%
# %pip install yfinance
# %pip install tables
# Out:
# Requirement already satisfied: yfinance in ./ats-venv/lib/python3.10/site-packages (0.2.3)
# Requirement already satisfied: html5lib>=1.1 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: cryptography>=3.3.2 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (39.0.0)
# Requirement already satisfied: multitasking>=0.0.7 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: pytz>=2022.5 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (2022.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: requests>=2.26 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (2.28.2)
# Requirement already satisfied: numpy>=1.16.5 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (1.24.1)
# Requirement already satisfied: pandas>=1.3.0 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (1.5.2)
# Requirement already satisfied: appdirs>=1.4.4 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in ./ats-venv/lib/python3.10/site-packages (from yfinance) (2.3.4)
# Requirement already satisfied: soupsieve>1.2 in ./ats-venv/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in ./ats-venv/lib/python3.10/site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: webencodings in ./ats-venv/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in ./ats-venv/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./ats-venv/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./ats-venv/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./ats-venv/lib/python3.10/site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./ats-venv/lib/python3.10/site-packages (from requests>=2.26->yfinance) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in ./ats-venv/lib/python3.10/site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: pycparser in ./ats-venv/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tables in ./ats-venv/lib/python3.10/site-packages (3.8.0)
# Requirement already satisfied: py-cpuinfo in ./ats-venv/lib/python3.10/site-packages (from tables) (9.0.0)
# Requirement already satisfied: cython>=0.29.21 in ./ats-venv/lib/python3.10/site-packages (from tables) (0.29.33)
# Requirement already satisfied: blosc2~=2.0.0 in ./ats-venv/lib/python3.10/site-packages (from tables) (2.0.0)
# Requirement already satisfied: numexpr>=2.6.2 in ./ats-venv/lib/python3.10/site-packages (from tables) (2.8.4)
# Requirement already satisfied: numpy>=1.19.0 in ./ats-venv/lib/python3.10/site-packages (from tables) (1.24.1)
# Requirement already satisfied: packaging in ./ats-venv/lib/python3.10/site-packages (from tables) (23.0)
# Requirement already satisfied: msgpack in ./ats-venv/lib/python3.10/site-packages (from blosc2~=2.0.0->tables) (1.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
from pathlib import Path
pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# ## Set Data Store path

# %% [markdown]
# Currently we will keep our data in the /data folder in which the current file resides. Modify path if you would like to store the data elsewhere and change the notebooks accordingly.

# %%
DATA_STORE = Path('assets.h5')

# %% [markdown]
# For the purpose of the paper, we have chosen a deversified portfolio of stocks - choosing different industries and countries from the top 100 tickers in the New York Stock Exchange. Here is a little information about the tickers we are going to work with:

# %% [markdown]
# |Country | Corporation | Ticker | Industry |
# | --- | --- | ---| --- |
# | United States | 3M | MMM | Industrial Goods |
# | China | Alibaba Group | BABA | Online Retail |
# | United States | Amazon | AMZN | Technology |
# | United States | Apple | AAPL | Technology |
# | Australia | BHP Group LTD | BHP | Metals |
# | United States | The Boeing Company | BA | Aerospace |
# | United Kingdom | BP p.l.c. | BP | Oil & Gas |
# | Sweden | Ericsson | ERIC | Telecommunications |
# | United States | Okta, Inc. | OKTA | CyberSecurity |
# | Japan | Toyota | TM | Automobiles & Parts |
# | Taiwan | Taiwan Semiconductor | TSM | Technology |
# | France | Sanofi | SNY | Pharmaceutical |
# | United States | Coca-Cola Consolidated, Inc. | COKE | Food & Beverage |
# | Netherlands | Aegon N.V. | AEG | Insurance |
# | United States | General Electric | GE | Conglomerate |
# | United States | Walmart Inc. | WMT | Retail |
# | United States | General Motors Company | GM | Automotive Manufacturing |
# | United States | Intel Corporation | INTC | Microprocessors Technology |
# | Japan | Canon Inc. | CAJ | Optical Imaging and more |
# | United States | Coinbase Global, Inc. | COIN | Crypto Exchange |

# %%
portfolio_tickers = ['MMM', 'BABA', 'AMZN', 'AAPL', 'BHP', 
                     'BA', 'BP', 'INTC', 'OKTA', 'TM', 
                     'TSM', 'SNY', 'COKE', 'AEG', 'GE', 
                     'WMT', 'GM', 'ERIC', 'CAJ', 'COIN', 'MSFT']

# %%
import yfinance as yt
import pandas as pd

tickers_dict = dict()
for ticker in portfolio_tickers:
    ticker_data = yt.Ticker(ticker)
    
    tickers_dict[ticker] = ticker_data 
    temp_prices = ticker_data.history(period="max")
    temp_prices = temp_prices.reset_index()
    temp_prices['Ticker'] = ticker
    temp_prices.to_csv('data/stock_prices.csv')

# %%
df_prices = (pd.read_csv('data/stock_prices.csv',
                 parse_dates=['Date'],
                 index_col=['Date', 'Ticker'],
                 infer_datetime_format=True)
     .sort_index())

print(df_prices.info(null_counts=True))
with pd.HDFStore(DATA_STORE) as store:
    store.put('yfinance/stock/prices', df_prices)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 9286 entries, (datetime.datetime(1986, 3, 13, 0, 0, tzinfo=tzoffset(None, -18000)), 'MSFT') to (datetime.datetime(2023, 1, 13, 0, 0, tzinfo=tzoffset(None, -18000)), 'MSFT')
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    9286 non-null   int64
#  1   Open          9286 non-null   float64
#  2   High          9286 non-null   float64
#  3   Low           9286 non-null   float64
#  4   Close         9286 non-null   float64
#  5   Volume        9286 non-null   int64
#  6   Dividends     9286 non-null   float64
#  7   Stock Splits  9286 non-null   float64
# dtypes: float64(6), int64(2)
# memory usage: 938.4+ KB
# None
# /var/folders/hp/29p2m8ms4vg51dy79knkbqgh0000gn/T/ipykernel_5888/583926772.py:7: FutureWarning: null_counts is deprecated. Use show_counts instead
#   print(df_prices.info(null_counts=True))
# /var/folders/hp/29p2m8ms4vg51dy79knkbqgh0000gn/T/ipykernel_5888/583926772.py:9: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->datetime,key->axis1_level0] [items->None]
#
#   store.put('yfinance/stock/prices', df_prices)

# %% [markdown]
# ## Loading Stock Meta Data

# %%
df_metadata = pd.read_csv('data/us_equities_meta_data.csv')
df_metadata = df_metadata.loc[df_metadata['ticker'].isin(portfolio_tickers)]
df_metadata
# Out:
#      ticker                                             name  lastsale     marketcap  ipoyear                 sector                                           industry
# 135    AMZN                                 Amazon.com, Inc.   1693.96  8.219500e+11   1997.0      Consumer Services                     Catalog/Specialty Distribution
# 191    AAPL                                       Apple Inc.    183.92  9.039900e+11   1980.0             Technology                             Computer Manufacturing
# 665    COKE              Coca-Cola Bottling Co. Consolidated    133.08  1.240000e+09   1972.0  Consumer Non-Durables                Beverages (Production/Distribution)
# 977    ERIC                                         Ericsson      7.62  2.505000e+10      NaN             Technology  Radio And Television Broadcasting And Communic...
# 1583   INTC                                Intel Corporation     49.47  2.305300e+11      NaN             Technology                                     Semiconductors
# 2048   MSFT                            Microsoft Corporation     99.05  7.610200e+11   1986.0             Technology            Computer Software: Prepackaged Software
# 2279   OKTA                                       Okta, Inc.     50.82  5.420000e+09   2017.0             Technology            Computer Software: Prepackaged Software
# 3690    MMM                                       3M Company    195.83  1.162600e+11      NaN            Health Care                         Medical/Dental Instruments
# 3733    AEG                                         Aegon NV      5.86  1.198000e+10      NaN                Finance                                     Life Insurance
# 3764   BABA                    Alibaba Group Holding Limited    184.75  4.740400e+11   2014.0          Miscellaneous                                  Business Services
# 4063    BHP                             BHP Billiton Limited     48.71  1.296600e+11      NaN       Basic Industries                                    Precious Metals
# 4154     BA                             Boeing Company (The)    332.93  1.939600e+11      NaN          Capital Goods                                          Aerospace
# 4167     BP                                        BP p.l.c.     45.90  1.528700e+11      NaN                 Energy                           Integrated oil Companies
# 4243    CAJ                                      Canon, Inc.     31.68  3.421000e+10      NaN          Miscellaneous                    Industrial Machinery/Components
# 4954     GE                         General Electric Company     13.37  1.161200e+11      NaN                 Energy                    Consumer Electronics/Appliances
# 4956     GM                           General Motors Company     38.97  5.493000e+10   2010.0          Capital Goods                                 Auto Manufacturing
# 6150    SNY                                           Sanofi     40.67  1.008200e+11      NaN            Health Care                              Major Pharmaceuticals
# 6369    TSM  Taiwan Semiconductor Manufacturing Company Ltd.     36.39  1.887200e+11   1997.0             Technology                                     Semiconductors
# 6498     TM                        Toyota Motor Corp Ltd Ord    127.40  1.883700e+11      NaN          Capital Goods                                 Auto Manufacturing
# 6702    WMT                                     Walmart Inc.     84.44  2.491700e+11      NaN      Consumer Services                 Department/Specialty Retail Stores

# %%
with pd.HDFStore(DATA_STORE) as store:
    store.put('us_equities/stocks', df_metadata.set_index('ticker'))
